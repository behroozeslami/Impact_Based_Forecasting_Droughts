# %%
import pandas as pd

# %% [markdown]
# ### Monthly Oceanic Nino Index (ONI)

# %%
ONI = pd.read_csv('Monthly Oceanic Nino Index (ONI) - Long.csv')
ONI.tail()
# Out:
#      Year MonthTxt  MonthNum PeriodTxt PeriodNum  Value
# 807  2017      MAM         4  2017-MAM   2017-04    0.4
# 808  2017      AMJ         5  2017-AMJ   2017-05    0.4
# 809  2017      MJJ         6  2017-MJJ   2017-06    0.2
# 810  2017      JJA         7  2017-JJA   2017-07   -0.1
# 811  2017      JAS         8  2017-JAS   2017-08   -0.5

# %%
Land_Temp = pd.read_csv('UG_LandSurfaceTemperature_adm_1.csv',sep=';')
Land_Temp.tail()
Land_Temp.geometry_pos.iloc[27689]
Land_Temp.geometry_pos.iloc[27689]
# Out:
# "{'type': 'Point', 'coordinates': [31.3734279, -0.052552]}"

# %%
Precipitation = pd.read_csv('UG_Precipitation_sum_adm_1.csv',sep=';')
Precipitation.tail()
# Out:
#       ADM0_EN  ADM0_EN_ft_style ADM0_PCODE  ADM0_PCODE_ft_style     ADM1_EN  \
# 55627  Uganda               0.0         UG                  0.0  SSEMBABULE
# 55628  Uganda               0.0         UG                  0.0      TORORO
# 55629  Uganda               0.0         UG                  0.0      WAKISO
# 55630  Uganda               0.0         UG                  0.0       YUMBE
# 55631  Uganda               0.0         UG                  0.0       ZOMBO
#
#       ADM1_PCODE  Month  OBJECTID  Year  \
# 55627      UG111     12     118.0  2018
# 55628      UG212     12     119.0  2018
# 55629      UG113     12     120.0  2018
# 55630      UG313     12     121.0  2018
# 55631      UG330     12     122.0  2018
#
#                                             geometry_pos  \
# 55627  {'type': 'Point', 'coordinates': [31.3734279, ...
# 55628  {'type': 'Point', 'coordinates': [34.1021976, ...
# 55629  {'type': 'Point', 'coordinates': [32.5130352, ...
# ...

# %%
SoilMoisture = pd.read_csv('UG_SoilMoisture_adm_1.csv',sep=';')
SoilMoisture.tail()
# Out:
#       ADM0_EN  ADM0_EN_ft_style ADM0_PCODE  ADM0_PCODE_ft_style     ADM1_EN  \
# 13171  Uganda               0.0         UG                  0.0  SSEMBABULE
# 13172  Uganda               0.0         UG                  0.0      TORORO
# 13173  Uganda               0.0         UG                  0.0      WAKISO
# 13174  Uganda               0.0         UG                  0.0       YUMBE
# 13175  Uganda               0.0         UG                  0.0       ZOMBO
#
#       ADM1_PCODE  Month  OBJECTID  Year  \
# 13171      UG111     12     118.0  2018
# 13172      UG212     12     119.0  2018
# 13173      UG113     12     120.0  2018
# 13174      UG313     12     121.0  2018
# 13175      UG330     12     122.0  2018
#
#                                             geometry_pos  \
# 13171  {'type': 'Point', 'coordinates': [31.3734279, ...
# 13172  {'type': 'Point', 'coordinates': [34.1021976, ...
# 13173  {'type': 'Point', 'coordinates': [32.5130352, ...
# ...

# %%
NDVI = pd.read_csv('UG_NDVI_adm_1.csv',sep=';')
NDVI.tail()
# Out:
#       ADM0_EN  ADM0_EN_ft_style ADM0_PCODE  ADM0_PCODE_ft_style     ADM1_EN  \
# 47575  Uganda               0.0         UG                  0.0  SSEMBABULE
# 47576  Uganda               0.0         UG                  0.0      TORORO
# 47577  Uganda               0.0         UG                  0.0      WAKISO
# 47578  Uganda               0.0         UG                  0.0       YUMBE
# 47579  Uganda               0.0         UG                  0.0       ZOMBO
#
#       ADM1_PCODE  Month  OBJECTID  Year  \
# 47575      UG111     12     118.0  2013
# 47576      UG212     12     119.0  2013
# 47577      UG113     12     120.0  2013
# 47578      UG313     12     121.0  2013
# 47579      UG330     12     122.0  2013
#
#                                             geometry_pos  \
# 47575  {'type': 'Point', 'coordinates': [31.3734279, ...
# 47576  {'type': 'Point', 'coordinates': [34.1021976, ...
# 47577  {'type': 'Point', 'coordinates': [32.5130352, ...
# ...
